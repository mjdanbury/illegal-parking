# %% [markdown]
# # Wrangling.ipynb
# This notebook contains the code for fetching the 311 complaint data from NYC Open Data's Socrata API

# %% [markdown]
# # 0. Imports

# %%
import pandas as pd
from sodapy import Socrata

# %%
from dotenv import load_dotenv
import os
load_dotenv()
app_token = os.getenv("APP_TOKEN")

# %% [markdown]
# # 1. Fetch and save 311 data

# %%
socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = 'erm2-nwe9'

client = Socrata(
    socrata_domain,
    app_token=app_token,
    timeout=100
)

query = """
SELECT
    *
WHERE
    complaint_type == 'Illegal Parking'
ORDER BY
    created_date DESC
LIMIT
    4000000
"""

results = client.get(
    socrata_dataset_identifier,
    query=query
)
client.close()

results_df = pd.DataFrame.from_records(results)

print('shape of data: {}'.format(results_df.shape))
results_df.head()
# Out:
# shape of data: (2451728, 35)
#   unique_key             created_date agency                      agency_name  \
# 0   60842145  2024-04-13T01:50:32.000   NYPD  New York City Police Department
# 1   60843192  2024-04-13T01:48:31.000   NYPD  New York City Police Department
# 2   60842166  2024-04-13T01:47:58.000   NYPD  New York City Police Department
# 3   60844395  2024-04-13T01:45:44.000   NYPD  New York City Police Department
# 4   60844160  2024-04-13T01:45:19.000   NYPD  New York City Police Department
#
#     complaint_type                     descriptor    location_type  \
# 0  Illegal Parking                Blocked Hydrant  Street/Sidewalk
# 1  Illegal Parking  Posted Parking Sign Violation  Street/Sidewalk
# 2  Illegal Parking   Commercial Overnight Parking  Street/Sidewalk
# 3  Illegal Parking              Blocked Crosswalk  Street/Sidewalk
# 4  Illegal Parking  Posted Parking Sign Violation  Street/Sidewalk
#
#   incident_zip       incident_address       street_name  ... park_borough  \
# 0        11223  1920 WEST    3 STREET  WEST    3 STREET  ...     BROOKLYN
# 1        11201       90 FURMAN STREET     FURMAN STREET  ...     BROOKLYN
# 2        11368       103-08 52 AVENUE         52 AVENUE  ...       QUEENS
# 3        11421  90-06 PARK LANE SOUTH   PARK LANE SOUTH  ...       QUEENS
# 4        11421        83-03 94 STREET         94 STREET  ...       QUEENS
#
#              latitude           longitude  \
# 0  40.600948272530495  -73.97546569381723
# 1  40.700888340143905  -73.99589219642144
# 2   40.74196903469716  -73.85761773970718
# 3   40.69719382744706  -73.85550269743995
# 4   40.69821019771289  -73.85181840080047
#
#                                             location  \
# 0  {'latitude': '40.600948272530495', 'longitude'...
# 1  {'latitude': '40.700888340143905', 'longitude'...
# 2  {'latitude': '40.74196903469716', 'longitude':...
# 3  {'latitude': '40.69719382744706', 'longitude':...
# 4  {'latitude': '40.69821019771289', 'longitude':...
#
#   resolution_action_updated_date closed_date resolution_description  \
# 0                            NaN         NaN                    NaN
# 1                            NaN         NaN                    NaN
# 2                            NaN         NaN                    NaN
# 3                            NaN         NaN                    NaN
# 4                            NaN         NaN                    NaN
#
#   vehicle_type due_date facility_type
# 0          NaN      NaN           NaN
# 1          NaN      NaN           NaN
# 2          NaN      NaN           NaN
# 3          NaN      NaN           NaN
# 4          NaN      NaN           NaN
#
# [5 rows x 35 columns]

# %%
results_df.to_csv('311_illegal_parking_041424.csv', index=False)

# %%
df = pd.read_csv('311_illegal_parking_041424.csv')
# Out:
# /var/folders/7g/_q1rw3r95gn9fptcst9g0v9c0000gn/T/ipykernel_26480/3133280043.py:1: DtypeWarning: Columns (14,16,32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('311_illegal_parking_041424.csv')

# %%
df['descriptor'].value_counts()
# Out:
# descriptor
# Blocked Hydrant                   686199
# Posted Parking Sign Violation     604601
# Blocked Sidewalk                  320395
# Commercial Overnight Parking      268257
# Double Parked Blocking Traffic    157968
# Blocked Bike Lane                 105021
# Double Parked Blocking Vehicle     98151
# Blocked Crosswalk                  61411
# Parking Permit Improper Use        50015
# Unauthorized Bus Layover           31046
# Overnight Commercial Storage       27106
# Paper License Plates               23356
# Detached Trailer                   10307
# License Plate Obscured              7895
# Name: count, dtype: int64
